# %%
import math
import torch
import torch.nn as nn
import torch.nn.functional as F

class MyDecodeLayer(nn.Module):
    def __init__(self, embed_dim: int, num_heads: int, ffn_dim: int):
        super().__init__()
        asser
